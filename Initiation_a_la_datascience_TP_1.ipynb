# %%
import pandas as pd

# %%
#Uploader un fichier
from google.colab import files
uploaded = files.upload()

# %%
from google.colab import drive
drive.mount("/content/drive")

customers = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/customers_export_1.csv')
orders = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/orders_export_1.csv')
products = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/products_export_1.csv')
visits = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/visits_2020-01-20_2021-11-20 (1).csv')
visitStatistiques = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/visits_2020-01-20_2021-11-20.csv')
sales = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/sales_2020-01-20_2021-11-20.csv')
saleStatistiques = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/sales_2020-01-20_2021-11-20 (1).csv')
# Out:
# Mounted at /content/drive

# %%
products.columns.to_list()
# Out:
# ['Handle',
#  'Title',
#  'Body (HTML)',
#  'Vendor',
#  'Standard Product Type',
#  'Custom Product Type',
#  'Tags',
#  'Published',
#  'Option1 Name',
#  'Option1 Value',
#  'Option2 Name',
#  'Option2 Value',
#  'Option3 Name',
#  'Option3 Value',
#  'Variant SKU',
#  'Variant Grams',
#  'Variant Inventory Tracker',
#  'Variant Inventory Policy',
#  'Variant Fulfillment Service',
#  'Variant Price',
#  'Variant Compare At Price',
#  'Variant Requires Shipping',
#  'Variant Taxable',
#  'Variant Barcode',
#  'Image Src',
#  'Image Position',
#  'Image Alt Text',
#  'Gift Card',
#  'SEO Title',
#  'SEO Description',
#  'Google Shopping / Google Product Category',
#  'Google Shopping / Gender',
#  'Google Shopping / Age Group',
#  'Google Shopping / MPN',
#  'Google Shopping / AdWords Grouping',
#  'Google Shopping / AdWords Labels',
#  'Google Shopping / Condition',
#  'Google Shopping / Custom Product',
#  'Google Shopping / Custom Label 0',
#  'Google Shopping / Custom Label 1',
# ...

# %%
products[products.Status == "active"]
# Out:
#                                          Handle  ...  Status
# 28        57-chocolat-chocolat-noir-au-coco-50g  ...  active
# 30             57-chocolat-chocolat-au-cafe-50g  ...  active
# 32    57-chocolat-chocolat-noir-aux-amandes-50g  ...  active
# 34               57-chocolat-chocolat-blanc-50g  ...  active
# 36          57-chocolat-chocolat-au-moringa-50g  ...  active
# ...                                         ...  ...     ...
# 3280                          eau-minerale-fifa  ...  active
# 3282                         eau-minerale-evian  ...  active
# 3283                       eau-minerale-contrex  ...  active
# 3284     lait-demaquillant-doux-250ml-evoluderm  ...  active
# 3285                  eau-micellaire-evoluderme  ...  active
#
# [1462 rows x 48 columns]
